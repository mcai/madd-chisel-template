# %% [markdown]
# <a href="https://colab.research.google.com/github/mcai/madd-chisel-template/blob/main/chisel_lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Install dependencies 安装依赖

# %%
# !apt-get update && apt-get install curl vim openjdk-11-jdk -y

# !mkdir -p /working/ && \
    cd /working/ && \
    curl -L -o sbt-1.4.9.deb https://repo.scala-sbt.org/scalasbt/debian/sbt-1.4.9.deb && \
    dpkg -i sbt-1.4.9.deb && \
    rm sbt-1.4.9.deb && \
    apt-get update && \
    apt-get install sbt -y && \
    cd && \
    rm -r /working/ && \
    sbt sbtVersion
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu focal-cran40/ InRelease [3,622 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  InRelease [1,581 B]
# Get:3 http://security.ubuntu.com/ubuntu focal-security InRelease [114 kB]
# Get:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  Packages [975 kB]
# Hit:5 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu focal InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu focal InRelease
# Get:7 http://archive.ubuntu.com/ubuntu focal-updates InRelease [114 kB]
# Hit:8 http://ppa.launchpad.net/cran/libgit2/ubuntu focal InRelease
# Get:9 http://security.ubuntu.com/ubuntu focal-security/main amd64 Packages [2,593 kB]
# Hit:10 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu focal InRelease
# Get:11 http://archive.ubuntu.com/ubuntu focal-backports InRelease [108 kB]
# Hit:12 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu focal InRelease
# ...

# %% [markdown]
# # 2. Run unit tests 执行单元测试

# %%
import os

repo_url = 'https://github.com/mcai/madd-chisel-template.git'
repo_name = 'madd-chisel-template'

if not os.path.exists(repo_name):
    # !git clone $repo_url
    # %cd $repo_name
else:
    # %cd $repo_name
    # !git pull

# !sbt "runMain madd.MatrixAddition1Tester"
# Out:
# Cloning into 'madd-chisel-template'...
# remote: Enumerating objects: 235, done.
# remote: Counting objects: 100% (235/235), done.
# remote: Compressing objects: 100% (130/130), done.
# remote: Total 235 (delta 88), reused 199 (delta 55), pack-reused 0
# Receiving objects: 100% (235/235), 53.05 KiB | 1.06 MiB/s, done.
# Resolving deltas: 100% (88/88), done.
# /content/madd-chisel-template/madd-chisel-template
# [info] welcome to sbt 1.4.9 (Ubuntu Java 11.0.18)
# [info] loading settings for project madd-chisel-template-build from plugins.sbt ...
# [info] loading project definition from /content/madd-chisel-template/madd-chisel-template/project
#
#   | => madd-chisel-template-build / update 0s
#
#   | => madd-chisel-template-build / Compile / compileIncremental 0s
# [info] loading settings for project root from build.sbt ...
# [info] set current project to madd-chisel-template (in build file:/content/madd-chisel-template/madd-chisel-template/)
#
#   | => root / dependencyPositions 0s
# ...
